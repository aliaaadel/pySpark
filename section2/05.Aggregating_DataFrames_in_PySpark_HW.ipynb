# %% [markdown]
# # Aggregating DataFrames in PySpark HW
#
# First let's start up our PySpark instance

# %%
import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
# May take awhile locally
spark = SparkSession.builder.appName("aggregate").getOrCreate()

cores = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
print("You are working with", cores, "core(s)")
spark
# Out:
# You are working with 1 core(s)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5ffde657c666:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>aggregate</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read in the dataFrame for this Notebook

# %%
airbnb = spark.read.csv('Datasets/nyc_air_bnb.csv',inferSchema=True,header=True)

# %% [markdown]
# ## About this dataset
#
# This dataset describes the listing activity and metrics for Air BNB bookers in NYC, NY for 2019. Each line in the dataset is a booking.
#
# **Source:** https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data/data
#
# Let's go ahead and view the first few records of the dataset so we know what we are working with.

# %%
airbnb.toPandas()
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 49074  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 49075  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 49076  36485431            Sunny Studio at Historical Neighborhood  23492952
# 49077  36485609               43rd St. Time Square-cozy single bed  30985759
# 49078  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 49074        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 49075        Marisol            Brooklyn            Bushwick  40.70184
# 49076  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 49077            Taz           Manhattan      Hell's Kitchen  40.75751
# 49078     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type price minimum_nights number_of_reviews  \
# 0      -73.97237     Private room   149              1                 9
# 1      -73.98377  Entire home/apt   225              1                45
# 2       -73.9419     Private room   150              3                 0
# 3      -73.95976  Entire home/apt    89              1               270
# 4      -73.94399  Entire home/apt    80             10                 9
# ...          ...              ...   ...            ...               ...
# 49074  -73.94995     Private room    70              2                 0
# 49075  -73.93317     Private room    40              4                 0
# 49076  -73.94867  Entire home/apt   115             10                 0
# 49077  -73.99112      Shared room    55              1                 0
# 49078  -73.98933     Private room    90              7                 0
#
#       last_review reviews_per_month calculated_host_listings_count  \
# 0      2018-10-19              0.21                              6
# 1      2019-05-21              0.38                              2
# 2            None              None                              1
# 3      2019-07-05              4.64                              1
# 4      2018-11-19              0.10                              1
# ...           ...               ...                            ...
# 49074        None              None                              2
# 49075        None              None                              2
# 49076        None              None                              1
# 49077        None              None                              6
# 49078        None              None                              1
#
#        availability_365
# 0                 365.0
# 1                 355.0
# 2                 365.0
# 3                 194.0
# 4                   0.0
# ...                 ...
# 49074               9.0
# 49075              36.0
# 49076              27.0
# 49077               2.0
# 49078              23.0
#
# [49079 rows x 16 columns]

# %% [markdown]
# Now print the schema so we can make sure all the variables have the correct types

# %%
airbnb.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- neighbourhood_group: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- minimum_nights: string (nullable = true)
#  |-- number_of_reviews: string (nullable = true)
#  |-- last_review: string (nullable = true)
#  |-- reviews_per_month: string (nullable = true)
#  |-- calculated_host_listings_count: string (nullable = true)
#  |-- availability_365: integer (nullable = true)

# %% [markdown]
# Notice here that some of the columns that are obviously numeric have been incorrectly identified as "strings". Let's edit that. Otherwise we cannot aggregate any of the numeric columns.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

airbnbNew = airbnb.withColumn("price", airbnb["price"].cast(IntegerType())) \
                    .withColumn("minimum_nights", airbnb["minimum_nights"].cast(IntegerType())) \
                    .withColumn("number_of_reviews", airbnb["number_of_reviews"].cast(IntegerType())) \
                    .withColumn("reviews_per_month", airbnb["reviews_per_month"].cast(IntegerType())) \
                    .withColumn("calculated_host_listings_count", airbnb["calculated_host_listings_count"].cast(IntegerType()))

# %%
airbnbNew.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- neighbourhood_group: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- minimum_nights: integer (nullable = true)
#  |-- number_of_reviews: integer (nullable = true)
#  |-- last_review: string (nullable = true)
#  |-- reviews_per_month: integer (nullable = true)
#  |-- calculated_host_listings_count: integer (nullable = true)
#  |-- availability_365: integer (nullable = true)

# %% [markdown]
# ### Alright now we are ready to dig in!
#
#
# ### 1. How many rows are in this dataset?

# %%
airbnbNew.count()
# Out:
# 49079

# %% [markdown]
# ### 2. How many total reviews does each host have?

# %%
airbnbNew.groupBy("host_id").agg({'number_of_reviews':'sum'}).show(5)
# Out:
# +-------+----------------------+
# |host_id|sum(number_of_reviews)|
# +-------+----------------------+
# | 716306|                   197|
# |1203500|                    35|
# | 368528|                     1|
# |1577493|                    16|
# |1390555|                    50|
# +-------+----------------------+
# only showing top 5 rows

# %% [markdown]
# ### 3. Show the min and max of all the numeric variables in the dataset

# %%
summary = airbnbNew.select("price","minimum_nights","number_of_reviews").summary('min', 'max')
summary.toPandas()
# Out:
#   summary  price minimum_nights number_of_reviews
# 0     min    -74              0                 0
# 1     max  10000           1250               629

# %% [markdown]
# ### 4. Which host had the highest number of reviews?
#
# Only display the top result.
#
# Bonus: format the column names

# %%
from pyspark.sql.functions import *
airbnbNew.groupBy('host_name').max('number_of_reviews').alias("max_reviews").show()
# Out:
# +------------+----------------------+
# |   host_name|max(number_of_reviews)|
# +------------+----------------------+
# |      Mary D|                     5|
# |      Alayna|                    27|
# |       Sandi|                    12|
# |    Laurence|                   156|
# |Paul & Elena|                    25|
# |       Tyler|                    14|
# |   Amaryllis|                     0|
# |       Tegan|                     1|
# |         Tmc|                    12|
# |     Susanna|                    37|
# |      Zaineb|                    70|
# |        Rony|                    54|
# |      Talisa|                     5|
# |      Genine|                     3|
# |    Pénélope|                     4|
# |        Faye|                    56|
# |       Yinny|                    48|
# |    Francois|                    10|
# |      Britta|                     5|
# |        Saad|                     6|
# +------------+----------------------+
# only showing top 20 rows

# %%
airbnbNew.sort(desc("price")).toPandas()
# Out:
#              id                                             name   host_id  \
# 0       7003697              Furnished room in Astoria apartment  20582832
# 1      13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 2      22436899                              1-BR Lincoln Center  72390391
# 3       4737930                               Spanish Harlem Apt   1235070
# 4       9528920              Quiet, Clean, Lit @ LES & Chinatown   3906464
# ...         ...                                              ...       ...
# 49074  36073776                     Amazing Room! Awesome Price!      None
# 49075  36077664                      Cozy Shared BR in East Side      None
# 49076  36169832                   Tiny Room only for “1 lady” :)      None
# 49077  36312667                               My Cozy Apartment!      None
# 49078  36381795                              Lovely one-bedroom;      None
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0      Kathrine              Queens          Astoria   40.7681  -73.91651
# 1          Erin            Brooklyn       Greenpoint   40.7326  -73.95739
# 2        Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 3         Olson           Manhattan      East Harlem  40.79264  -73.93898
# 4           Amy           Manhattan  Lower East Side  40.71355  -73.98507
# ...         ...                 ...              ...       ...        ...
# 49074      None                None             None      None       None
# 49075      None                None             None      None       None
# 49076      None                None             None      None       None
# 49077      None                None             None      None       None
# 49078      None                None             None      None       None
#
#              room_type    price  minimum_nights  number_of_reviews  \
# 0         Private room  10000.0           100.0                2.0
# 1      Entire home/apt  10000.0             5.0                5.0
# 2      Entire home/apt  10000.0            30.0                0.0
# 3      Entire home/apt   9999.0             5.0                1.0
# 4         Private room   9999.0            99.0                6.0
# ...                ...      ...             ...                ...
# 49074             None      NaN             NaN                NaN
# 49075             None      NaN             NaN                NaN
# 49076             None      NaN             NaN                NaN
# 49077             None      NaN             NaN                NaN
# 49078             None      NaN             NaN                NaN
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2016-02-13                0.0                             1.0
# 1      2017-07-27                0.0                             1.0
# 2            None                NaN                             1.0
# 3      2015-01-02                0.0                             1.0
# 4      2016-01-01                0.0                             1.0
# ...           ...                ...                             ...
# 49074        None                NaN                             NaN
# 49075        None                NaN                             NaN
# 49076        None                NaN                             NaN
# 49077        None                NaN                             NaN
# 49078        None                NaN                             NaN
#
#        availability_365
# 0                   0.0
# 1                   0.0
# 2                  83.0
# 3                   0.0
# 4                  83.0
# ...                 ...
# 49074               NaN
# 49075               NaN
# 49076               NaN
# 49077               NaN
# 49078               NaN
#
# [49079 rows x 16 columns]

# %% [markdown]
# ### 5. On average, how many nights did most hosts specify for a minimum?

# %%
airbnbNew.groupBy('host_name').avg('minimum_nights').alias("avg_min_nights").show()
# Out:
# +------------+-------------------+
# |   host_name|avg(minimum_nights)|
# +------------+-------------------+
# |      Mary D|                7.0|
# |      Alayna|                3.5|
# |       Sandi|                2.0|
# |    Laurence| 2.8461538461538463|
# |Paul & Elena|                3.0|
# |       Tyler|  4.483870967741935|
# |   Amaryllis|                1.0|
# |       Tegan|                2.0|
# |         Tmc|                3.0|
# |     Susanna|                5.0|
# |      Zaineb|                4.0|
# |        Rony|               3.25|
# |      Talisa|                1.0|
# |      Genine|                2.0|
# |    Pénélope|                1.0|
# |        Faye|  5.916666666666667|
# |       Yinny|                3.5|
# |    Francois|               3.75|
# |      Britta|  7.333333333333333|
# |        Saad|                4.0|
# +------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### 6. What is the most expensive neighborhood to stay in on average?
#
# Note: only show the one result

# %%
airbnbNew.groupBy("neighbourhood_group").max("price").alias('max').show()
# Out:
# +-------------------+----------+
# |neighbourhood_group|max(price)|
# +-------------------+----------+
# |         Douglaston|         1|
# |             Queens|     10000|
# |              Nadia|      null|
# |            Midtown|        30|
# |     Hell's Kitchen|         3|
# |  Greenwich Village|        80|
# |       Clinton Hill|        14|
# |   Ditmars Steinway|         6|
# |           Longwood|         5|
# |        Little Neck|         1|
# |           Flushing|        28|
# |               null|      null|
# |         Bath Beach|         2|
# |        East Harlem|         3|
# |            Astoria|        21|
# |       East Village|         7|
# |        Fort Greene|         1|
# |         Mott Haven|         1|
# |           Gramercy|         2|
# |       Williamsburg|        30|
# +-------------------+----------+
# only showing top 20 rows

# %% [markdown]
# ### 7. Display a two by two table that shows the average prices by room type (private and shared only) and neighborhood group (Manhattan and Brooklyn only)

# %%
airbnbNew.filter(airbnbNew.room_type.isin(['Shared room','Private room'])).groupBy("room_type").pivot("neighbourhood_group", ["Manhattan", "Brooklyn"]).avg('price').show(10)
# Out:
# +------------+------------------+-----------------+
# |   room_type|         Manhattan|         Brooklyn|
# +------------+------------------+-----------------+
# | Shared room| 89.06903765690376|50.52784503631961|
# |Private room|116.05400302114803|76.47234042553191|
# +------------+------------------+-----------------+

# %% [markdown]
# ### Alright that's all folks!
#
# ### Great job!
